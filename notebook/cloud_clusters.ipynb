# %%
from IPython.display import Image

# %%
Image(filename='../png/sample_complex_voxel.png')

# %% [markdown]
# For the entire cloud field, we can take the 2D clusters and project it onto a 2D space:

# %%
Image(filename='../png/plot_projected_clouds.png')

# %%
Image(filename='../png/plot_hist_vs_kde.png')

# %% [markdown]
#  Same plot for the 12 km domain:

# %%
Image(filename='../png/plot_hist_vs_kde_BOMEX_12HR.png')

# %%
Image(filename='../png/plot_linear_regression.png')

# %%
Image(filename='../png/plot_linear_regression_BOMEX_12HR.png')

# %%
Image(filename='../png/plot_cloud_size_dist.png')
